# %% [markdown]
# ## cifar100

# %%
dataset = 'cifar100'
positions = ['B0 Inc5', 'B0 Inc10', 'B0 Inc20', 'B50 Inc5','B50 Inc10']
mos = [[94.84,94.78,93.28,94.08,94.18],[94.8,94.68,93.42,94.09,94.15],[94.8,94.68,93.42,94.09,94.15]]
ease = [[93.11,92.56,91.61,90.35,89.2],[93.09,92.54,91.66,90.41,89.28],[93.09,92.54,91.66,90.41,89.28]]
simple_cil = [[81.12,82.31,82.79,78.66,78.54],[81.12,82.31,82.79,78.66,78.54],[81.12,82.31,82.79,78.66,78.54]]
coda_prompt = [[92.85,91.49,88.9,86.38,77.81],[92.85,91.59,88.86,85.95,77.71],[92.85,91.59,88.86,85.95,77.71]]
dual_prompt = [[91.4,90.34,88.51,87.48,80.99],[91.38,90.25,88.53,87.49,81.04],[91.38,90.25,88.53,87.49,81.04]]
l2p = [[90.81,89.86,87.58,87.61,79.42],[90.68,89.84,87.58,87.49,79.44],[90.68,89.84,87.58,87.49,79.44]]
foster_cnn = [[93.74,93.68,93.71,92.2,92.15],[93.74,93.68,93.71,92.2,92.15],[93.74,93.68,93.71,92.2,92.15]]
foster_nme = [[93.7,93.9,93.69,92.26,92.22],[93.7,93.9,93.69,92.26,92.22],[93.7,93.9,93.69,92.26,92.22]]
der_cnn = [[88.78,88.58,88.57,86.83,86.56],[88.78,88.58,88.57,86.83,86.56],[88.78,88.58,88.75,87.1,86.53]]
der_nme = [[91.36,91.01,90.85,89.38,88.98],[91.36,91.01,90.85,89.38,88.98],[91.36,91.01,91.17,89.47,89.08]]
icarl_cnn = [[87.34,85.74,84.07,83.46,80.67],[87.04,85.99,84.61,83.37,81.65],[87.04,85.99,84.61,83.37,81.65]]
icarl_nme = [[90.9,90.22,89.43,88.83,87.06],[90.75,90.33,89.47,88.96,87.55],[90.75,90.33,89.47,88.96,87.55]]
finetune = [[81.48,76.93,72.14,82.2,79.99],[81.48,76.93,72.14,82.2,79.99],[81.48,76.93,72.14,82.2,79.99]]

# %% [markdown]
# ## cub200

# %%
dataset = 'cub200'
positions = ['B0 Inc5', 'B0 Inc10', 'B0 Inc20', 'B100 Inc5','B100 Inc10']
mos = [[92.75,93.27,93.48,91.45,91.43],[92.75,93.27,93.48,91.45,91.43],[92.75,93.27,93.48,91.45,91.43]]
ease = [[90.2, 90.19, 91.34, 85.29, 87.54],[90.07,90.22,91.31,85.23,87.38],[90.15,90.22,91.31,85.26,87.41]]
simple_cil = [[89.93, 90.58, 90.97, 87.56, 87.48],[89.92,90.56,90.96,87.48,87.4],[89.92,90.56,90.96,87.48,87.4]]
coda_prompt = [[85.65, 85.01, 82.92, 79.6, 76.63],[85.85,84.9,83.1,79.63,76.35],[85.85,84.89,83.08,79.55,76.33]]
dual_prompt = [[85.48, 84.87, 82.96, 77.06, 73.87],[85.48,84.87,82.96,77.06,73.87],[85.54,84.79,82.79,76.91,73.66]]
l2p = [[83.79, 81.76, 79.32, 79.4, 74.62],[83.7,81.76,79.34,79.05,74.64],[83.72,81.87,79.34,79.01,74.68]]
foster_cnn = [[78.55, 80.7, 86.03, 82.98, 85.55],[78.32,81.27,84.99,82.38,85.55],[79.55,81.58,84.49,82.58,85.57]]
foster_nme = [[90.58, 91.05, 91.89, 89.17, 88.7],[90.69,90.81,91.14,88.79,88.7],[90.67,91.2,91.18,88.8,88.75]]
der_cnn = [[89.73, 88.1, 90.09, 87.28, 86.76],[88.57,88.1,90.09,87.28,86.76],[88.95,89.93,90.2,86.86,86.64]]
der_nme = [[89.82, 88.93, 91.02, 88.7, 88.49],[90.15,88.93,91.02,88.7,88.49],[89.7,90.44,90.92,88.47,88.05]]
icarl_cnn = [[87.42, 88.27, 88.07, 85.9, 85.47],[87.94,88.31,87.83,85.56,84.86],[87.94,88.02,88.69,86.33,85.88]] 
icarl_nme = [[89.12, 90.13, 89.9, 88.11, 87.53],[89.03,89.84,90.4,87.77,86.87],[89.03,89.86,90.29,87.86,87.35]]
finetune = [[78.05, 71.38, 61.57, 73.38, 63.81],[77.02,71.55,56.51,72.91,64.02],[77.02,69.9,62.54,72.36,59.12]]

# %% [markdown]
# ## inr

# %%
# 2 3 runs 在同一张卡
dataset = 'inr'
positions = ['B0 Inc5', 'B0 Inc10', 'B0 Inc20', 'B100 Inc5','B100 Inc10']
mos = [[82.79,82.63,81.28,81.09,81.11],[82.79,82.63,81.28,81.09,81.11],[82.79,82.63,81.28,81.09,81.11]]
ease = [[81.6, 80.92, 78.9, 77.95, 76.59],[81.52,81.06,78.87,77.97,76.57],[81.52,81.06,78.87,77.97,76.57]]
simple_cil = [[65.89, 67.09, 67.6, 63.55, 63.43],[65.84,67.06,67.58,63.52,63.4],[65.84,67.06,67.58,63.52,63.4]]
coda_prompt = [[79.99, 78.63, 74.27, 73.15, 67.83],[79.86,78.76,74.54,73.08,67.88],[79.86,78.76,74.54,73.08,67.88]]
dual_prompt = [[73.51, 70.97, 69.92, 64.82, 59.55],[73.55,71.25,69.8,65.15,59.82],[73.55,71.25,69.8,65.15,59.82]]
l2p = [[76.85, 76.26, 73.7, 69.7, 64.89],[76.9,76.34,73.68,69.81,64.88],[76.9,76.34,73.68,69.81,64.88]]
foster_cnn = [[81.33,82.38,82.37,80.16,80.67],[81.93,82.48,48.53,80.68,80.91],[81.33,82.38,82.65,79.78,80.54]]
foster_nme = [[85.78,85.59,84.86,83.96,83.49],[85.65,85.8,49.63,83.64,83.3],[85.78,85.59,84.82,83.36,83.23]]
der_cnn = [[80.9,80.75,79.78,79.11,79.48],[80.27,81.16,80.09,80.06,79.48],[80.9,80.72,80.09,79.43,79.67]]
der_nme = [[83.85,83.32,82.93,81.43,81.69],[83.71,83.87,82.59,81.58,81.69],[83.85,83.82,82.59,82.22,82.05]]
icarl_cnn = [[75.27,72.0,70.11,71.46,67.44],[75.53,72.63,68.97,71.56,67.64],[75.27,72.0,70.11,71.03,68.27]] 
icarl_nme = [[80.63,78.92,78.18,77.59,74.33],[80.79,79.18,77.56,77.35,74.73],[80.63,78.92,78.18,77.04,74.67]]
finetune = [[71.64, 68.97, 64.41, 70.76, 67.11],[72.54,67.99,60.72,70.71,66.52],[72.54,67.99,60.72,70.71,66.52]]

# %% [markdown]
# ## ina

# %%
dataset = 'ina'
positions = ['B0 Inc5', 'B0 Inc10', 'B0 Inc20', 'B100 Inc5','B100 Inc10']
mos = [[65.56,66.8,64.14,64.93,64.88],[65.56,66.8,64.14,64.93,64.88],[65.56,66.8,64.14,64.93,64.88]]
ease = [[67.96, 62.58, 57.68, 63.06, 62.19],[67.78,62.71,58.35,63.8,62.18],[67.78,62.71,58.35,63.8,62.18]]
simple_cil = [[58.09, 59.33, 60.05, 53.29, 53.21],[58.53,59.68,60.5,53.62,53.54],[58.53,59.68,60.5,53.62,53.54]]
coda_prompt = [[61.0, 56.06, 47.77, 56.61, 52.92],[60.98,56.43,47.54,56.06,53.34],[60.98,56.43,47.54,56.06,53.34]]
dual_prompt = [[54.01, 52.47, 48.44, 46.87, 44.59],[54.23,52.41,48.66,47.1,45.28],[54.23,52.41,48.66,47.1,45.28]]
l2p = [[53.24, 52.57, 45.68, 49.12, 46.74],[53.49,52.74,46.06,49.42,46.91],[53.49,52.74,46.06,49.42,46.91]]
finetune = [[38.53, 32.03, 7.28, 31.16, 24.54],[37.78,34.58,19.25,29.9,24.7],[37.78,34.58,19.25,29.9,24.7]]

# %% [markdown]
# ## omn

# %%
# 1st-omn 2nd-omn 3rd-omn-std顺序统计
dataset = 'omn'
positions = ['B0 Inc5', 'B0 Inc10', 'B0 Inc20','B0 Inc30','B150 Inc5','B150 Inc10']
mos = [[85.59,85.93,85.93,86.04,83.51,83.26],[85.59,85.93,85.93,86.04,83.51,83.26],[85.59,85.93,85.93,86.04,83.51,83.26]]
ease = [[75.79,74.84,74.75,74.24,71.68,69.18],[75.79,74.84,74.75,74.24,71.68,69.18],[75.79,74.84,74.75,74.24,71.68,69.18]]#,[75.79,74.84,74.75,74.24,71.68,69.18]]
simple_cil = [[77.73,78.51,79.18,79.46,74.47,74.32],[77.87,78.61,79.27,79.55,74.56,74.42],[77.87,78.61,79.27,79.55,74.56,74.42]]#,[77.87,78.61,79.27,79.55,74.56,74.42]]
coda_prompt = [[80.04,77.01,75.14,74.31,70.36,63.14],[80.04,77.01,75.14,74.31,70.36,63.14],[80.04,77.01,75.14,74.31,70.36,63.14]]#,[80.04,77.01,75.14,74.31,70.36,63.14]]
dual_prompt = [[79.39,74.9,74.85,73.54,71.51,63.95],[79.36,74.9,74.85,73.67,71.51,63.95],[79.36,75.0,74.81,73.54,71.51,63.95]]#,[79.39,74.9,74.85,73.54,71.51,63.95]]
l2p = [[77.99,74.18,72.84,71.19,70.16,63.41],[77.99,74.14,72.66,71.1,70.18,63.37],[77.99,74.14,72.66,71.1,70.18,63.37]]#,[77.99,74.18,72.84,71.19,70.16,63.41]]
foster_cnn = [[77.87,77.88,81.27,81.7,79.1,79.97],[77.87,77.88,81.27,81.7,79.1,79.97],[78.16,78.47,80.95,81.2,79.09,79.79]]#,[77.87,77.88,81.27,81.7,79.1,79.97]]
foster_nme = [[83.86,82.62,83.4,82.96,81.42,81.17],[83.86,82.62,83.4,82.96,81.42,81.17],[83.42,83.2,83.14,82.82,81.71,81.25]]#,[83.86,82.62,83.4,82.96,81.42,81.17]]
der_cnn = [[77.49,77.53,77.21,77.16,77.14,76.49],[78.51,77.7,76.67,77.16,77.14,76.49],[78.51,77.7,77.46,77.16,76.81,76.4]]#,[78.41,77.85,76.67,77.16,77.14,76.49]]
der_nme = [[81.15,80.74,80.26,79.24,79.4,78.74],[82.0,80.8,79.84,79.24,79.4,78.74],[82.0,80.8,80.16,79.24,79.84,78.46]]#,[81.8,80.63,79.84,79.24,79.4,78.74]]
icarl_cnn = [[76.8,75.26,73.38,73.94,74.39,72.23],[76.25,74.46,74.02,72.76,73.97,72.46],[76.25,74.46,74.02,72.76,73.97,72.46]]#,[76.79,75.47,72.94,73.42,74.6,72.41]]
icarl_nme = [[82.5,80.94,79.78,79.77,79.13,78.41],[82.0,80.92,80.12,79.45,79.11,77.88],[82.0,80.92,80.12,79.45,79.11,77.88]]#,[82.43,81.39,79.32,79.85,79.14,77.78]]
finetune = [[70.21,65.12,60.77,57.2,68.37,64.1],[70.54,66.21,60.84,57.82,68.01,64.83],[70.54,66.21,60.84,57.82,68.01,64.83]]#,[70.5,65.8,60.09,56.82,68.63,64.85]]

# %% [markdown]
# ## vtab

# %%
dataset = 'vtab'
positions = ['B0 Inc5', 'B0 Inc10']
mos = [[92.59,93.18],[92.59,93.18],[92.59,93.18]]
ease = [[90.47, 91.07],[90.47,91.07],[90.47,91.07]]
simple_cil = [[90.94, 91.66],[90.94,91.66],[90.94,91.66]]
coda_prompt = [[87.82, 83.36],[87.82,83.36],[87.82,83.36]]
dual_prompt = [[89.96, 87.61],[89.96,87.61],[89.96,87.61]]
l2p = [[82.11, 78.04],[82.11,78.04],[82.11,78.04]]
finetune = [[78.69, 59.2],[78.69,59.2],[78.69,59.2]]

# %% [markdown]
# ## 绘图-Markdown版

# %%
import numpy as np
import matplotlib.pyplot as plt

# 定义一个函数来计算均值和方差
def calc_mean_std(data):
    mean_values = np.around(np.mean(data, axis=0), decimals=2)
    std_values = np.around(np.std(data, axis=0), decimals=2)
    return mean_values.tolist(), std_values.tolist()
# 计算每个模型的均值和方差
mos_mean, mos_std = calc_mean_std(mos)
ease_mean, ease_std = calc_mean_std(ease)
coda_prompt_mean, coda_prompt_std = calc_mean_std(coda_prompt)
dual_prompt_mean, dual_prompt_std = calc_mean_std(dual_prompt)
l2p_mean, l2p_std = calc_mean_std(l2p)
simple_cil_mean, simple_cil_std = calc_mean_std(simple_cil)
finetune_mean, finetune_std = calc_mean_std(finetune)
print("|MOS", "|" + "|".join([f"{mean} ± {std}" for mean, std in zip(mos_mean, mos_std)]) + "|")
print("|Ease", "|" + "| ".join([f"{mean} ± {std}" for mean, std in zip(ease_mean, ease_std)]) + "|")
print("|CODA-Prompt", "|" + "|".join([f"{mean} ± {std}" for mean, std in zip(coda_prompt_mean, coda_prompt_std)]) + "|")
print("|DualPrompt", "|" + "|".join([f"{mean} ± {std}" for mean, std in zip(dual_prompt_mean, dual_prompt_std)]) + "|")
print("|L2P", "|" + "|".join([f"{mean} ± {std}" for mean, std in zip(l2p_mean, l2p_std)]) + "|")
print("|SimpleCIL", "|" + "|".join([f"{mean} ± {std}" for mean, std in zip(simple_cil_mean, simple_cil_std)]) + "|")
print("|Finetune", "|" + "|".join([f"{mean} ± {std}" for mean, std in zip(finetune_mean, finetune_std)]) + "|")    
  
marker = ['o', 's', 'D', '^',  '>',  'p', 'h','<','v','*','+', 'x', 'D', 'd', '|', '_']
colors = ['#43978F', "#9467bd",'#ED9F9B','#84C2AE', '#E56F5E', '#F6C957','#589CD6', '#FFB77F',"#17becf",'#BD514A','#AED185', '#EF7E33', '#B395BD', '#F9F871']

datasets = [  
    ('MOS', mos_mean),
    ('EASE', ease_mean),
    ('CODA-Prompt', coda_prompt_mean),
    ('Dual-Prompt', dual_prompt_mean),
    ('L2P', l2p_mean),
    ('Simple-CIL', simple_cil_mean),
    ('Fine-tune', finetune_mean)
]

if dataset == 'inr' or dataset == 'ina' or dataset == 'vtab':
    pass
else:
    if dataset == 'omn':
        positions = ['B0 Inc5', 'B0 Inc10', 'B0 Inc20','B0 Inc30','B150 Inc5','B150 Inc10']
    else:
        positions = ['B0 Inc5', 'B0 Inc10', 'B0 Inc20', 'B100 Inc5','B100 Inc10']
    foster_cnn_mean, foster_cnn_std = calc_mean_std(foster_cnn)
    foster_nme_mean, foster_nme_std = calc_mean_std(foster_nme)
    der_cnn_mean, der_cnn_std = calc_mean_std(der_cnn)
    der_nme_mean, der_nme_std = calc_mean_std(der_nme)
    icarl_cnn_mean, icarl_cnn_std = calc_mean_std(icarl_cnn)
    icarl_nme_mean, icarl_nme_std = calc_mean_std(icarl_nme)
    datasets.append(('Foster-CNN', foster_cnn_mean))
    datasets.append(('Foster-NME', foster_nme_mean))
    datasets.append(('DER-CNN', der_cnn_mean))
    datasets.append(('DER-NME', der_nme_mean))
    datasets.append(('iCaRL-CNN', icarl_cnn_mean))
    datasets.append(('iCaRL-NME', icarl_nme_mean))
    print("|FOSTER-CNN", "|" + "|".join([f"{mean} ± {std}" for mean, std in zip(foster_cnn_mean, foster_cnn_std)]) + "|")
    print("|FOSTER-NME", "|" + "|".join([f"{mean} ± {std}" for mean, std in zip(foster_nme_mean, foster_nme_std)]) + "|")
    print("|DER-CNN", "|" + "|".join([f"{mean} ± {std}" for mean, std in zip(der_cnn_mean, der_cnn_std)]) + "|")
    print("|DER-NME", "|" + "|".join([f"{mean} ± {std}" for mean, std in zip(der_nme_mean, der_nme_std)]) + "|")
    print("|iCaRL-CNN", "|" + "|".join([f"{mean} ± {std}" for mean, std in zip(icarl_cnn_mean, icarl_cnn_std)]) + "|")
    print("|iCaRL-NME", "|" + "|".join([f"{mean} ± {std}" for mean, std in zip(icarl_nme_mean, icarl_nme_std)]) + "|")
    
plt.figure(dpi=300, figsize=(4, 3))  # 设置图表分辨率和尺寸
i = 0
for name, data in datasets:  
    plt.plot(positions,data,label=name,marker=marker[i],color = colors[i], markersize=2,linewidth=1)  
    i+=1
  
# 设置图表标题和坐标轴标签  
# plt.xlabel('Inc', fontsize=6)  
plt.ylabel('Accuracy(%)', fontsize=6)  

plt.xticks(fontsize=6)
plt.yticks(fontsize=6)
  
# 设置图例  
plt.legend(fontsize=5,loc='lower left',ncol=2)  # 设置图例位置 
  
# 显示网格  
# plt.grid(True)  
  
# 调整x轴刻度，使数据点更易读  
# plt.xticks(param_counts_backbone, positions, rotation=45)  
  
# 显示图表  
plt.show()
# Out:
# |MOS |92.59 ± 0.0|93.18 ± 0.0|
# |Ease |90.47 ± 0.0| 91.07 ± 0.0|
# |CODA-Prompt |87.82 ± 0.0|83.36 ± 0.0|
# |DualPrompt |89.96 ± 0.0|87.61 ± 0.0|
# |L2P |82.11 ± 0.0|78.04 ± 0.0|
# |SimpleCIL |90.94 ± 0.0|91.66 ± 0.0|
# |Finetune |78.69 ± 0.0|59.2 ± 0.0|

# %% [markdown]
# ## 绘图-计算版

# %%
import numpy as np
import matplotlib.pyplot as plt

# 定义一个函数来计算均值和方差
def calc_mean_std(data):
    mean_values = np.around(np.mean(data, axis=0), decimals=2)
    std_values = np.around(np.std(data, axis=0), decimals=2)
    return mean_values.tolist(), std_values.tolist()
# 计算每个模型的均值和方差
ease_mean, ease_std = calc_mean_std(ease)
coda_prompt_mean, coda_prompt_std = calc_mean_std(coda_prompt)
dual_prompt_mean, dual_prompt_std = calc_mean_std(dual_prompt)
l2p_mean, l2p_std = calc_mean_std(l2p)
simple_cil_mean, simple_cil_std = calc_mean_std(simple_cil)
finetune_mean, finetune_std = calc_mean_std(finetune)
print("ease:", "[" + ", ".join([f"{mean} ± {std}" for mean, std in zip(ease_mean, ease_std)]) + "]")
print("coda_prompt:", "[" + ", ".join([f"{mean} ± {std}" for mean, std in zip(coda_prompt_mean, coda_prompt_std)]) + "]")
print("dual_prompt:", "[" + ", ".join([f"{mean} ± {std}" for mean, std in zip(dual_prompt_mean, dual_prompt_std)]) + "]")
print("l2p:", "[" + ", ".join([f"{mean} ± {std}" for mean, std in zip(l2p_mean, l2p_std)]) + "]")
print("simple_cil:", "[" + ", ".join([f"{mean} ± {std}" for mean, std in zip(simple_cil_mean, simple_cil_std)]) + "]")
print("finetune:", "[" + ", ".join([f"{mean} ± {std}" for mean, std in zip(finetune_mean, finetune_std)]) + "]")    
# print("coda_prompt:", coda_prompt_mean, coda_prompt_std)
# print("dual_prompt:", dual_prompt_mean, dual_prompt_std)
# print("l2p:", l2p_mean, l2p_std)
# print("simple_cil:", simple_cil_mean, simple_cil_std)
# print("finetune:", finetune_mean, finetune_std)
  
marker = ['o', 's', 'D', '^',  '>',  'p', 'h','<','v','*','+', 'x', 'D', 'd', '|', '_']
colors = ['#43978F', '#9EC4BE', '#B192B4', '#E56F5E', '#F6C957','#589CD6', '#E57259','#FFB77F','#BD514A','#AAD390', '#EF7E33', '#F7C242', '#F9F871']

datasets = [  
    ('EASE', ease_mean),
    ('CODA-Prompt', coda_prompt_mean),
    ('Dual-Prompt', dual_prompt_mean),
    ('L2P', l2p_mean),
    ('Simple-CIL', simple_cil_mean),
    ('Fine-tune', finetune_mean)
]
positions = ['B0 Inc5', 'B0 Inc10', 'B0 Inc20', 'B50 Inc5','B50 Inc10']
if dataset == 'inr' or dataset == 'ina' or dataset == 'vtab':
    if dataset == 'vtab':
        positions = ['B0 Inc5', 'B0 Inc10']
else:
    foster_cnn_mean, foster_cnn_std = calc_mean_std(foster_cnn)
    foster_nme_mean, foster_nme_std = calc_mean_std(foster_nme)
    der_cnn_mean, der_cnn_std = calc_mean_std(der_cnn)
    der_nme_mean, der_nme_std = calc_mean_std(der_nme)
    icarl_cnn_mean, icarl_cnn_std = calc_mean_std(icarl_cnn)
    icarl_nme_mean, icarl_nme_std = calc_mean_std(icarl_nme)
    datasets.append(('Foster-CNN', foster_cnn_mean))
    datasets.append(('Foster-NME', foster_nme_mean))
    datasets.append(('DER-CNN', der_cnn_mean))
    datasets.append(('DER-NME', der_nme_mean))
    datasets.append(('iCaRL-CNN', icarl_cnn_mean))
    datasets.append(('iCaRL-NME', icarl_nme_mean))
    print("Foster-CNN:", "[" + ", ".join([f"{mean} ± {std}" for mean, std in zip(foster_cnn_mean, foster_cnn_std)]) + "]")
    print("Foster-NME:", "[" + ", ".join([f"{mean} ± {std}" for mean, std in zip(foster_nme_mean, foster_nme_std)]) + "]")
    print("DER-CNN:", "[" + ", ".join([f"{mean} ± {std}" for mean, std in zip(der_cnn_mean, der_cnn_std)]) + "]")
    print("DER-NME:", "[" + ", ".join([f"{mean} ± {std}" for mean, std in zip(der_nme_mean, der_nme_std)]) + "]")
    print("iCaRL-CNN:", "[" + ", ".join([f"{mean} ± {std}" for mean, std in zip(icarl_cnn_mean, icarl_cnn_std)]) + "]")
    print("iCaRL-NME:", "[" + ", ".join([f"{mean} ± {std}" for mean, std in zip(icarl_nme_mean, icarl_nme_std)]) + "]")
    # print("Foster-CNN:", foster_cnn_mean, foster_cnn_std)
    # print("Foster-NME:", foster_nme_mean, foster_nme_std)
    # print("DER-CNN:", der_cnn_mean, der_cnn_std)
    # print("DER-NME:", der_nme_mean, der_nme_std)
    # print("iCaRL-CNN:", icarl_cnn_mean, icarl_cnn_std)
    # print("iCaRL-NME:", icarl_nme_mean, icarl_nme_std)
    
plt.figure(dpi=300, figsize=(4, 3))  # 设置图表分辨率和尺寸
i = 0
for name, data in datasets:  
    plt.plot(positions,data,label=name,marker=marker[i],color = colors[i], markersize=2,linewidth=1)  
    i+=1
  
# 设置图表标题和坐标轴标签  
# plt.xlabel('Inc', fontsize=6)  
plt.ylabel('Accuracy(%)', fontsize=6)  

plt.xticks(fontsize=6)
plt.yticks(fontsize=6)
  
# 设置图例  
plt.legend(fontsize=5,loc='lower left',ncol=2)  # 设置图例位置 
  
# 显示网格  
# plt.grid(True)  
  
# 调整x轴刻度，使数据点更易读  
# plt.xticks(param_counts_backbone, positions, rotation=45)  
  
# 显示图表  
plt.show()
# Out:
# ease: [90.14 ± 0.05, 90.21 ± 0.01, 91.32 ± 0.01, 85.26 ± 0.02, 87.44 ± 0.07]
# coda_prompt: [85.78 ± 0.09, 84.93 ± 0.05, 83.03 ± 0.08, 79.59 ± 0.03, 76.44 ± 0.14]
# dual_prompt: [85.5 ± 0.03, 84.84 ± 0.04, 82.9 ± 0.08, 77.01 ± 0.07, 73.8 ± 0.1]
# l2p: [83.74 ± 0.04, 81.8 ± 0.05, 79.33 ± 0.01, 79.15 ± 0.18, 74.65 ± 0.02]
# simple_cil: [89.92 ± 0.0, 90.57 ± 0.01, 90.96 ± 0.0, 87.51 ± 0.04, 87.43 ± 0.04]
# finetune: [77.36 ± 0.49, 70.94 ± 0.74, 60.21 ± 2.64, 72.88 ± 0.42, 62.32 ± 2.26]
# Foster-CNN: [78.81 ± 0.53, 81.18 ± 0.36, 85.17 ± 0.64, 82.65 ± 0.25, 85.56 ± 0.01]
# Foster-NME: [90.65 ± 0.05, 91.02 ± 0.16, 91.4 ± 0.34, 88.92 ± 0.18, 88.72 ± 0.02]
# DER-CNN: [89.08 ± 0.48, 88.71 ± 0.86, 90.13 ± 0.05, 87.14 ± 0.2, 86.72 ± 0.06]
# DER-NME: [89.89 ± 0.19, 89.43 ± 0.71, 90.99 ± 0.05, 88.62 ± 0.11, 88.34 ± 0.21]
# iCaRL-CNN: [87.77 ± 0.25, 88.2 ± 0.13, 88.2 ± 0.36, 85.93 ± 0.32, 85.4 ± 0.42]
# iCaRL-NME: [89.06 ± 0.04| 89.94 ± 0.13| 90.2 ± 0.21| 87.91 ± 0.14| 87.25 ± 0.28]
